# %% [markdown]
# # Lab 10 - Dictionaries and Election Data
#
# ---

# %% [markdown]
# ## Importing Modules

# %%
import matplotlib.pyplot as pp

# %% [markdown]
# ## Reading in the data

# %%
def test_get_election_results():
    # TODO: update inputs and expected outputs of the test cases. Delete this line when you are done.

    #votes for all candidates in all regions
    input = ''
    expected = ()
    actual = get_election_results(input)

    if actual == expected:
        print("Test 1 PASSED")
    else:
        print("Test 1 FAILED!")
        print("Expected:", expected)
        print("Actual:", actual)

    #TODO: fill out test equivalency class
    input = ''
    expected = ()
    actual = get_election_results(input)

    if actual == expected:
        print("Test 2 PASSED")
    else:
        print("Test 2 FAILED!")
        print("Expected:", expected)
        print("Actual:", actual)

    #TODO: fill out test equivalency class
    input = ''
    expected = ()
    actual = get_election_results(input)

    if actual == expected:
        print("Test 3 PASSED")
    else:
        print("Test 3 FAILED!")
        print("Expected:", expected)
        print("Actual:", actual)

# %%
def get_election_results(election_filename):
    """
    Replace this with a correctly formatted docstring for the function.
    """

    pass  # placeholder. Remove this line when you have implemented the function.

# %%
test_get_election_results()

# %% [markdown]
# ---
#
# ## Example of creating a pie chart

# %%
pie_labels = ("Cats", "Dogs", "Cows")
pie_colors = ("purple", "orange", "black")
data = [12, 4, 18]
pp.pie(data, labels=pie_labels, colors=pie_colors)

pp.title("Number of Animals on Dr. Sat's Farm")
pp.show()

# %% [markdown]
# ---
#
# ## Creating the pie chart

# %%
# To Do: 
# Step 1 - Read in from the user (with an appropriate prompt) the 
# name of a data file containing election data.  The code should go right 
# below this comment.

# To Do: 
# Step 2 - Call your get_election_results function with the user
# specified filename to get the candidate names and a dictionary with 
# the voting data. The code should go right below this comment.

# To Do: 
# Step 3 - Read in from the user (with an appropriate prompt) the 
# name of a region from the election data election data.  Check if the
# region specified by the user is in dictionary of election data.  If it
# is not, print a descriptive message to the user.  Otherwise, go on to the
# next step.  The code should go right below this comment.

# To Do: 
# Step 4 - Use pyplot's pie function to make a pie chart out of the
# election data for the user-entered region.
# Each wedge of the pie should be labeled with the candidate's name and
# should have the "traditional" coloring (red for Republican, blue for
# Democratic, and black for third-party/other).
# You should set the title for the pie chart that reads "Election results for
# California", but modified so that "California" is replaced with whatever
# region name the user entered. The code should go right below this comment.
